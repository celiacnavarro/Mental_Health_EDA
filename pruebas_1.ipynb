# %%
import numpy as np
import pandas as pd

# %%
prevalencias = pd.read_csv('data/prevalence-by-mental-and-substance-use-disorder.csv')

# %%
prevalencias
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                              0.228979
# 1                                              0.228120
# 2                                              0.227328
# 3                                              0.226468
# 4                                              0.225567
# ...                                                 ...
# 6835                                           0.209359
# 6836                                           0.209979
# 6837                                           0.210631
# ...

# %%
disorders = ['Schizofrenia', 'Bipolar disorder', 'Eating disorders', 'Anxiety disorders', 'Drug use disorders', 'Depressive disorders', 'Alcohol use disorders']
for col in prevalencias.columns:
    for i in disorders:
        if i in col:
            prevalencias.rename(columns={col:i}, inplace=True)
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                              0.228979
# 1                                              0.228120
# 2                                              0.227328
# 3                                              0.226468
# 4                                              0.225567
# ...                                                 ...
# 6835                                           0.209359
# 6836                                           0.209979
# 6837                                           0.210631
# ...

# %%
prevalencias.rename(columns={'Entity': 'Country'}, inplace=True)
prevalencias.drop(columns='Code', inplace=True)
#transformando variables!

# %%
prevalencias.columns
# Out:
# Index(['Country', 'Year',
#        'Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'],
#       dtype='object')

# %%
for i in range(2,9):
    new_name = prevalencias.columns[i].split()[2]
    prevalencias.rename(columns={prevalencias.columns[i]: new_name}, inplace=True)
    print(new_name)

#cambiando los nombres de las variables
# Out:
# Schizophrenia
# Bipolar
# Eating
# Anxiety
# Drug
# Depressive
# Alcohol

# %%
prevalencias.info()

#no hay valores nulos :D
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        6840 non-null   object
#  1   Year           6840 non-null   int64
#  2   Schizophrenia  6840 non-null   float64
#  3   Bipolar        6840 non-null   float64
#  4   Eating         6840 non-null   float64
#  5   Anxiety        6840 non-null   float64
#  6   Drug           6840 non-null   float64
#  7   Depressive     6840 non-null   float64
#  8   Alcohol        6840 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 481.1+ KB

# %%
prevalencias.describe()
# Out:
#               Year  Schizophrenia      Bipolar       Eating      Anxiety  \
# count  6840.000000    6840.000000  6840.000000  6840.000000  6840.000000
# mean   2004.500000       0.281167     0.673891     0.211062     4.327525
# std       8.656074       0.047561     0.258594     0.152559     1.177961
# min    1990.000000       0.191621     0.189344     0.045425     1.974823
# 25%    1997.000000       0.255468     0.539791     0.099857     3.567064
# 50%    2004.500000       0.287456     0.591893     0.154143     4.094443
# 75%    2012.000000       0.304760     0.897248     0.276891     4.797286
# max    2019.000000       0.506018     1.676204     1.136541     9.015948
#
#               Drug   Depressive      Alcohol
# count  6840.000000  6840.000000  6840.000000
# mean      0.746708     3.950449     1.578807
# std       0.463026     0.921021     0.934655
# min       0.225471     1.640902     0.319900
# 25%       0.423502     3.258977     0.732826
# ...

# %%
prevalencias.groupby('Country').agg('mean')
# Out:
#                                   Year  Schizophrenia   Bipolar    Eating  \
# Country
# Afghanistan                     2004.5       0.223277  0.719665  0.109910
# African Region (WHO)            2004.5       0.217597  0.583824  0.103411
# Albania                         2004.5       0.301066  0.576012  0.121142
# Algeria                         2004.5       0.262260  0.796430  0.205404
# American Samoa                  2004.5       0.324998  0.294477  0.137566
# ...                                ...            ...       ...       ...
# World Bank Lower Middle Income  2004.5       0.279718  0.425711  0.107286
# World Bank Upper Middle Income  2004.5       0.306117  0.455243  0.139165
# Yemen                           2004.5       0.236623  0.743373  0.137764
# Zambia                          2004.5       0.211477  0.581043  0.101546
# Zimbabwe                        2004.5       0.211275  0.556468  0.105859
#
# ...

# %%
df = prevalencias

# %%
df[df['Country'].str.contains('WHO')]['Country'].unique()
# Out:
# array(['African Region (WHO)', 'Eastern Mediterranean Region (WHO)',
#        'European Region (WHO)', 'Region of the Americas (WHO)',
#        'South-East Asia Region (WHO)', 'Western Pacific Region (WHO)'],
#       dtype=object)

# %%
dfcont = df[df['Country'].str.contains('WHO')].copy()

# %%
dfcont.rename(columns={'Country': 'Continent'}, inplace=True)

# %%
df[df['Country'].str.contains('Bank')]['Country'].unique()
# Out:
# array(['World Bank High Income', 'World Bank Low Income',
#        'World Bank Lower Middle Income', 'World Bank Upper Middle Income'],
#       dtype=object)

# %%
dfincome = df[df['Country'].str.contains('Bank')].copy()

# %%
dfincome.rename(columns={'Country': 'Income'}, inplace=True)

# %%
df = df[~df.Country.str.contains("WHO")]
df = df[~df.Country.str.contains("Bank")]
