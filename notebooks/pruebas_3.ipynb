# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/share-with-depression.csv')

# %%
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6775     Zimbabwe  ZWE  2015
# 6776     Zimbabwe  ZWE  2016
# 6777     Zimbabwe  ZWE  2017
# 6778     Zimbabwe  ZWE  2018
# 6779     Zimbabwe  ZWE  2019
#
#       Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)
# 0                                              5.125291
# 1                                              5.116306
# 2                                              5.106558
# 3                                              5.100328
# 4                                              5.099424
# ...                                                 ...
# 6775                                           3.548613
# 6776                                           3.557508
# 6777                                           3.564138
# 6778                                           3.563141
# 6779                                           3.554571
#
# [6780 rows x 4 columns]

# %%
df.rename(columns={'Entity': 'Country',
                 df.columns[3] : 'Prev Depression'},
                 inplace=True)
df.drop(columns='Code', inplace=True)
#transformando variables!

# %%
df
# Out:
#           Country  Year  Prev Depression
# 0     Afghanistan  1990         5.125291
# 1     Afghanistan  1991         5.116306
# 2     Afghanistan  1992         5.106558
# 3     Afghanistan  1993         5.100328
# 4     Afghanistan  1994         5.099424
# ...           ...   ...              ...
# 6775     Zimbabwe  2015         3.548613
# 6776     Zimbabwe  2016         3.557508
# 6777     Zimbabwe  2017         3.564138
# 6778     Zimbabwe  2018         3.563141
# 6779     Zimbabwe  2019         3.554571
#
# [6780 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6780 entries, 0 to 6779
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          6780 non-null   object
#  1   Year             6780 non-null   int64
#  2   Prev Depression  6780 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 159.0+ KB

# %%
df[df['Country'].str.contains('WHO')]['Country'].unique()
dfcont = df[df['Country'].str.contains('WHO')].copy()
dfcont.rename(columns={'Country': 'Continent'}, inplace=True)

# %%
df[df['Country'].str.contains('Bank')]['Country'].unique()
dfincome = df[df['Country'].str.contains('Bank')].copy()
dfincome.rename(columns={'Country': 'Income'}, inplace=True)

# %%
df = df[~df.Country.str.contains("WHO")]
df = df[~df.Country.str.contains("Bank")]
