# %%
import pandas as pd

# %%
class DataInfo:
    def __init__(self,df):
        self.df = df

    def info(self): 
        
        # Numero de filas
        print(f'\nFilas totales : {self.df.shape[0]} \n')
      
        # Numero de columnas
        print(f'\nColumnas totales : {self.df.shape[1]} \n')
        
        # Nombres de las columnas
        column_name =  self.df.columns 
        print(f'\nNombres de las columnas\n'+  f'\n{column_name} \n \n')
        
        # Tipo de datos (info)
        print(f'Info de los datos\n')
        data_summary = self.df.info() 
        
        # Valores nulos 
        null_values = self.df.isnull().sum() 
        print(f'\nValores nulos\n' +  f'\n{null_values} \n \n')

        # Estadística descriptiva
        describe =  self.df.describe() 
        print(f'\nEstadística descriptiva\n' + f'\n{describe} \n \n')
    
    def clean(self):
        # Cambiamos el nombre de la columna
        self.df.rename(columns={'Entity': 'Country'}, inplace=True)
        # Eliminamos una columna
        self.df.drop(columns='Code', inplace=True)
        print(self.df.columns)
    
    def dfcont(self):
        x = self.df[self.df['Country'].str.contains('WHO')].copy()
        x.rename(columns={'Country': 'Continent'}, inplace=True)
        return x
    def dfincome(self):
        x = self.df[self.df['Country'].str.contains('Bank')].copy()
        x.rename(columns={'Country': 'Income'}, inplace=True)
        return x

# %%
a = pd.read_csv('data/prevalence-by-mental-and-substance-use-disorder.csv')

# %%
aa = DataInfo(a)
aa.clean()
# Out:
# Index(['Country', 'Year',
#        'Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)',
#        'Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)'],
#       dtype='object')

# %%
a_dfincome = aa.dfincome()

# %%
a_dfincome
# Out:
#                               Income  Year  \
# 6630          World Bank High Income  1990
# 6631          World Bank High Income  1991
# 6632          World Bank High Income  1992
# 6633          World Bank High Income  1993
# 6634          World Bank High Income  1994
# ...                              ...   ...
# 6745  World Bank Upper Middle Income  2015
# 6746  World Bank Upper Middle Income  2016
# 6747  World Bank Upper Middle Income  2017
# 6748  World Bank Upper Middle Income  2018
# 6749  World Bank Upper Middle Income  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 6630                                           0.349837
# 6631                                           0.351302
# 6632                                           0.352642
# 6633                                           0.353803
# 6634                                           0.354764
# ...                                                 ...
# 6745                                           0.308526
# 6746                                           0.310809
# 6747                                           0.313086
# 6748                                           0.312974
# 6749                                           0.312283
#
#       Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 6630                                           0.786395
# 6631                                           0.787030
# 6632                                           0.787801
# 6633                                           0.788598
# 6634                                           0.789333
# ...                                                 ...
# 6745                                           0.475078
# 6746                                           0.477434
# 6747                                           0.479685
# 6748                                           0.481878
# 6749                                           0.484107
#
#       Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 6630                                           0.390832
# 6631                                           0.397064
# 6632                                           0.402772
# 6633                                           0.407782
# 6634                                           0.411640
# ...                                                 ...
# 6745                                           0.164308
# 6746                                           0.168254
# 6747                                           0.171563
# 6748                                           0.173578
# 6749                                           0.175025
#
#       Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 6630                                           5.080294
# 6631                                           5.081799
# 6632                                           5.084536
# 6633                                           5.087854
# 6634                                           5.091523
# ...                                                 ...
# 6745                                           4.093712
# 6746                                           4.138800
# 6747                                           4.185851
# 6748                                           4.192571
# 6749                                           4.181423
#
#       Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 6630                                           1.377799
# 6631                                           1.394368
# 6632                                           1.410451
# 6633                                           1.425537
# 6634                                           1.438795
# ...                                                 ...
# 6745                                           0.706593
# 6746                                           0.725803
# 6747                                           0.746686
# 6748                                           0.748686
# 6749                                           0.747494
#
#       Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)  \
# 6630                                           3.728780
# 6631                                           3.743666
# 6632                                           3.761546
# 6633                                           3.781520
# 6634                                           3.802907
# ...                                                 ...
# 6745                                           3.329720
# 6746                                           3.331579
# 6747                                           3.332059
# 6748                                           3.330413
# 6749                                           3.322933
#
#       Prevalence - Alcohol use disorders - Sex: Both - Age: Age-standardized (Percent)
# 6630                                           2.238104
# 6631                                           2.219053
# 6632                                           2.199737
# 6633                                           2.181322
# 6634                                           2.164989
# ...                                                 ...
# 6745                                           1.514542
# 6746                                           1.511265
# 6747                                           1.511673
# 6748                                           1.517199
# 6749                                           1.520577
#
# [120 rows x 9 columns]

# %%
# Out:
# <__main__.DataInfo object at 0x00000209A0247548>
